# %% [markdown]
# # **Prediction Model – Xgboost**

# %%
# Import packages
import pandas as pd
import numpy as np
import sklearn as sci
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LassoCV
from sklearn.feature_selection import SelectFromModel

# %% [markdown]
# ## Read the data

# %%
# Read the data
data = pd.read_csv('/Users/vanessahuang/Desktop/BI_capstone/信義房屋/data/0326(初版).csv')
data.head()
# Out:
#                                    物件編號        土地位置建物門牌  土地移轉總面積平方公尺 都市土地使用分區  \
# 0  4a4ac3d4-6e86-4a70-85de-d3928f0caf83    承德路四段６巷５４號三樓        29.50        住
# 1  b6f193bf-6477-4813-9135-4d9998716c0a     福國路９５號七樓之２３        11.67        商
# 2  be5b4051-8505-4aab-b03a-9f2441a93988  南京東路三段３４６號十樓之４        10.84        住
# 3  22be66be-02d5-4f5f-a89d-ccc31ea7c063  八德路四段６０４號二樓之１７        27.35        商
# 4  3ef80e6a-3eb7-4aaa-940a-b75709a6d22e   新生北路三段１號十三樓之６         2.35        商
#
#      交易年月日      移轉層次  總樓層數       主要建材  建物移轉總面積平方公尺  建物現況格局-房  ...  車位類別_其他  \
# 0  1100101  三層，電梯樓梯間     4  鋼筋混凝土加強磚造        86.21         3  ...        0
# 1  1100101        七層     8        NaN        71.23         3  ...        0
# 2  1100101        十層    12     鋼筋混凝土造        82.75         2  ...        0
# 3  1100101        二層    12     鋼筋混凝土造       169.77         1  ...        0
# 4  1100101       十三層    14     鋼筋混凝土造        22.61         1  ...        0
#
#    車位類別_升降平面  車位類別_升降機械  車位類別_坡道平面  車位類別_坡道機械  車位類別_塔式車位  土地  建物 車位   建物年齡
# 0          0          0          0          0          0   1   1  0  18701
# 1          0          0          0          0          0   1   1  0  15849
# 2          0          0          0          0          0   2   1  0  15687
# 3          0          0          0          0          0   1   2  0  11826
# 4          0          0          0          0          0   1   1  0  14589
#
# [5 rows x 96 columns]

# %%
# Check some basic information
print(data.columns)
print('-----' * 30)
print(data.shape)
# Out:
# Index(['物件編號', '土地位置建物門牌', '土地移轉總面積平方公尺', '都市土地使用分區', '交易年月日', '移轉層次', '總樓層數',
#        '主要建材', '建物移轉總面積平方公尺', '建物現況格局-房', '建物現況格局-廳', '建物現況格局-衛', '建物現況格局-隔間',
#        '有無管理組織', '總價元', '單價元平方公尺', '車位移轉總面積平方公尺', '車位總價元', '備註', '主建物面積',
#        '附屬建物面積', '陽台面積', '電梯', '年份', '月份', '里數', '鄰數_現有門牌', '鄰數_戶籍登記',
#        '人口數_總和', '人口數_男', '人口數_女', '戶數', '消費者物價指數', '失業率_%', '緯度', '經度', 'A',
#        'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'X', '景氣對策信號(分)',
#        '租金指數', '收盤指數', '可能成交價指數', '五大行庫平均房貸利率(%)', '行政區_中山區', '行政區_中正區',
#        '行政區_信義區', '行政區_內湖區', '行政區_北投區', '行政區_南港區', '行政區_士林區', '行政區_大同區',
#        '行政區_大安區', '行政區_文山區', '行政區_松山區', '行政區_萬華區', '交易標的_建物', '交易標的_房地(土地+建物)',
#        '交易標的_房地(土地+建物)+車位', '建物型態_住宅大樓(11層含以上有電梯)', '建物型態_公寓(5樓含以下無電梯)',
#        '建物型態_套房(1房1廳1衛)', '建物型態_華廈(10層含以下有電梯)', '建物型態_透天厝', '主要用途_住商用',
#        '主要用途_住商辦用', '主要用途_住家用', '主要用途_住工用', '主要用途_其他', '主要用途_商業用', '主要用途_商辦用',
#        '主要用途_工商用', '主要用途_工業用', '主要用途_辦公用', '主要用途_農業用', '車位類別_一樓平面', '車位類別_其他',
#        '車位類別_升降平面', '車位類別_升降機械', '車位類別_坡道平面', '車位類別_坡道機械', '車位類別_塔式車位', '土地',
#        '建物', '車位', '建物年齡'],
#       dtype='object')
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# (49286, 96)
